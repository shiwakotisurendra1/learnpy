# %%
import pandas as pd

# %%
df = pd.read_excel(r"D:\befragung\kerpen_befragung\data_infotool_2024-10-09_16-52.xlsx",skiprows=[1])


# Convert datetime columns to strings
for column in df.select_dtypes(include=['datetime64[ns]', 'datetime64']).columns:
    df[column] = df[column].dt.strftime('%Y-%m-%d %H:%M:%S')

df.head()
# Out:
#     CASE          QUESTNNR       MODE              STARTED  \
# 0   98.0  Co-Site_InfoTool  interview  2024-07-30 11:14:35
# 1  101.0  Co-Site_InfoTool  interview  2024-07-30 11:40:18
# 2  102.0  Co-Site_InfoTool  interview  2024-07-30 11:44:08
# 3  104.0  Co-Site_InfoTool  interview  2024-07-30 11:58:35
# 4  108.0  Co-Site_InfoTool  interview  2024-07-30 12:18:11
#
#                                              GE01_01  GE02  \
# 0  Abteilung Strategisches Projektmanagement und ...   1.0
# 1                                                NaN   1.0
# 2                                                NaN   2.0
# 3                                               16.1   1.0
# 4                                  16.1 Stadtplanung   1.0
#
#                                              GE03_01  \
# 0     Anliegenmelder über das Beteiligungsportal NRW
# 1                              Liegenschaftskataster
# 2                                                NaN
# ...

# %%
df['STARTED'][1]
# Out:
# '2024-07-30 11:40:18'
